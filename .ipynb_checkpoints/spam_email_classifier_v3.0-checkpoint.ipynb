# %% [markdown]
# # Import Libraries

# %%
import re
import string
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator
import nltk
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

# %% [markdown]
# # Load Data

# %%
df = pd.read_csv('spam.csv', encoding="latin-1")
df.head()
# Out:
#      v1                                                 v2 Unnamed: 2  \
# 0   ham  Go until jurong point, crazy.. Available only ...        NaN
# 1   ham                      Ok lar... Joking wif u oni...        NaN
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...        NaN
# 3   ham  U dun say so early hor... U c already then say...        NaN
# 4   ham  Nah I don't think he goes to usf, he lives aro...        NaN
#
#   Unnamed: 3 Unnamed: 4
# 0        NaN        NaN
# 1        NaN        NaN
# 2        NaN        NaN
# 3        NaN        NaN
# 4        NaN        NaN

# %%
df.shape
# Out:
# (5572, 5)

# %% [markdown]
# # Data Cleaning

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5572 entries, 0 to 5571
# Data columns (total 5 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   v1          5572 non-null   object
#  1   v2          5572 non-null   object
#  2   Unnamed: 2  50 non-null     object
#  3   Unnamed: 3  12 non-null     object
#  4   Unnamed: 4  6 non-null      object
# dtypes: object(5)
# memory usage: 217.8+ KB

# %%
df = df.dropna(how="any", axis=1)
df.columns = ['target', 'text']

df.head()
# Out:
#   target                                               text
# 0    ham  Go until jurong point, crazy.. Available only ...
# 1    ham                      Ok lar... Joking wif u oni...
# 2   spam  Free entry in 2 a wkly comp to win FA Cup fina...
# 3    ham  U dun say so early hor... U c already then say...
# 4    ham  Nah I don't think he goes to usf, he lives aro...

# %%
from sklearn.preprocessing import LabelEncoder

encoder = LabelEncoder()
encoder.fit(df['target'])

df['target'] = encoder.transform(df['target'])
df.head()
# Out:
#    target                                               text
# 0       0  Go until jurong point, crazy.. Available only ...
# 1       0                      Ok lar... Joking wif u oni...
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...
# 3       0  U dun say so early hor... U c already then say...
# 4       0  Nah I don't think he goes to usf, he lives aro...

# %%
# missing value
df.isnull().sum()
# Out:
# target    0
# text      0
# dtype: int64

# %%
# check duplicate value
df.duplicated().sum()
# Out:
# 403

# %%
# drop duplicate rows
df = df.drop_duplicates(keep='first')
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# # EDA

# %%
# count target
df.target.value_counts()
# Out:
# 0    4516
# 1     653
# Name: target, dtype: int64

# %%
import matplotlib.pyplot as plt
plt.pie(df.target.value_counts(), labels=['ham', 'spam'], autopct='%0.2f')
plt.show()

# %% [markdown]
# - `Data is unbalanced`

# %%
import nltk
df['num_characters'] = df['text'].apply(len)
df['num_words'] = df['text'].apply(lambda x: len(nltk.word_tokenize(x)))
df['num_sentances'] = df['text'].apply(lambda x: len(nltk.sent_tokenize(x)))

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentances
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
# ham
df[df['target'] == 0][['num_characters', 'num_words', 'num_sentances']].describe()
# Out:
#        num_characters    num_words  num_sentances
# count     4516.000000  4516.000000    4516.000000
# mean        70.459256    17.120903       1.799601
# std         56.358207    13.493725       1.278465
# min          2.000000     1.000000       1.000000
# 25%         34.000000     8.000000       1.000000
# 50%         52.000000    13.000000       1.000000
# 75%         90.000000    22.000000       2.000000
# max        910.000000   220.000000      28.000000

# %%
# spam
df[df['target'] == 1][['num_characters', 'num_words', 'num_sentances']].describe()
# Out:
#        num_characters   num_words  num_sentances
# count      653.000000  653.000000     653.000000
# mean       137.891271   27.667688       2.967841
# std         30.137753    7.008418       1.483201
# min         13.000000    2.000000       1.000000
# 25%        132.000000   25.000000       2.000000
# 50%        149.000000   29.000000       3.000000
# 75%        157.000000   32.000000       4.000000
# max        224.000000   46.000000       8.000000

# %%
# chart
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 1]['num_characters'], color='red', alpha=1)
sns.histplot(df[df['target'] == 0]['num_characters'], color='green', alpha=0.4)
plt.show()

# %%
# chart
plt.figure(figsize=(12,6))
sns.histplot(df[df['target'] == 1]['num_words'], color='red', alpha=1)
sns.histplot(df[df['target'] == 0]['num_words'], color='green', alpha=0.4)
plt.show()

# %%
sns.pairplot(df, hue='target')
plt.show()

# %%
sns.heatmap(df.corr(), annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Data Preprocessing
#
# - lower case
# - Tokenization
# - Removing Special Charactor
# - Remove stopwords and punctuation
# - stemming

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentances
# 0         24              2
# 1          8              2
# 2         37              2
# 3         13              1
# 4         15              1

# %%
stemmer = nltk.SnowballStemmer("english") # stemmer

# Stopwords
stop_words = stopwords.words('english')
more_stopwords = ['u', 'im', 'c']
stop_words = stop_words + more_stopwords

def clean_text(text):
    '''Make text lowercase, remove text in square brackets,remove links,remove punctuation
    and remove words containing numbers.'''
    text = str(text).lower()
    
    # Clean Text with removing speacial Charactor
    text = re.sub('\[.*?\]', '', text)
    text = re.sub('https?://\S+|www\.\S+', '', text)
    text = re.sub('<.*?>+', '', text)
    text = re.sub('[%s]' % re.escape(string.punctuation), '', text)
    text = re.sub('\n', '', text)
    text = re.sub('\w*\d\w*', '', text)
    
    text = ' '.join(word for word in text.split(' ') if word not in stop_words) # Remove Stopwords
    text = ' '.join(stemmer.stem(word) for word in text.split(' ')) # stemming
    return text

# %%
df['clean_text'] = df['text'].apply(clean_text)

# %%
df.head()
# Out:
#    target                                               text  num_characters  \
# 0       0  Go until jurong point, crazy.. Available only ...             111
# 1       0                      Ok lar... Joking wif u oni...              29
# 2       1  Free entry in 2 a wkly comp to win FA Cup fina...             155
# 3       0  U dun say so early hor... U c already then say...              49
# 4       0  Nah I don't think he goes to usf, he lives aro...              61
#
#    num_words  num_sentances                                         clean_text
# 0         24              2  go jurong point crazi avail bugi n great world...
# 1          8              2                                ok lar joke wif oni
# 2         37              2  free entri  wkli comp win fa cup final tkts  m...
# 3         13              1                      dun say earli hor alreadi say
# 4         15              1          nah dont think goe usf live around though

# %%
twitter_mask = np.array(Image.open('twitter_mask3.jpeg'))

wc = WordCloud(
    background_color='white', 
    max_words=250, 
    mask=twitter_mask,
)
wc.generate(' '.join(text for text in df.loc[df['target'] == 0, 'clean_text']))
plt.figure(figsize=(18,10))
plt.title('Top words for HAM messages', 
          fontdict={'size': 22,  'verticalalignment': 'bottom'})
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
twitter_mask = np.array(Image.open('twitter_mask3.jpeg'))

wc = WordCloud(
    background_color='white', 
    max_words=500, 
    mask=twitter_mask,
)
wc.generate(' '.join(text for text in df.loc[df['target'] == 1, 'clean_text']))
plt.figure(figsize=(18,10))
plt.title('Top words for HAM messages', 
          fontdict={'size': 22,  'verticalalignment': 'bottom'})
plt.imshow(wc)
plt.axis("off")
plt.show()

# %%
ham_corpus = " ".join(df[df['target'] == 0]['clean_text'].tolist()).split()
print(len(ham_corpus))
# Out:
# 34513

# %%
from collections import Counter
most_common_ham_words = pd.DataFrame(Counter(ham_corpus).most_common(30))
sns.barplot(x=most_common_ham_words[0], y=most_common_ham_words[1])
plt.xticks(rotation='vertical')
plt.xlabel('Most Common Words')
plt.ylabel("Frequency of words")
plt.title("Most Common word in ham Corpus")
plt.show()

# %%
spam_corpus = " ".join(df[df['target'] == 1]['clean_text'].tolist()).split()
print(len(spam_corpus))
# Out:
# 8403

# %%
from collections import Counter
most_common_spam_words = pd.DataFrame(Counter(spam_corpus).most_common(30))
sns.barplot(x=most_common_spam_words[0], y=most_common_spam_words[1])
plt.xticks(rotation='vertical')
plt.xlabel('Most Common Words')
plt.ylabel("Frequency of words")
plt.title("Most Common word in Spam Corpus")
plt.show()

# %%
from sklearn.feature_extraction.text import CountVectorizer

# instantiate the vectorizer
vect = CountVectorizer()
X_vect = vect.fit_transform(df['clean_text']).toarray()

# %%
X_vect.shape
# Out:
# (5169, 6737)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# instantiate the vectorizer
tfidf = TfidfVectorizer(max_features=3000)
X_tfidf = tfidf.fit_transform(df['clean_text']).toarray()

# %%
X_tfidf.shape
# Out:
# (5169, 3000)

# %%
y = df['target'].values

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size = 0.2)

# %% [markdown]
# # Model Building

# %%
from sklearn.naive_bayes import GaussianNB, MultinomialNB, BernoulliNB
from sklearn.metrics import accuracy_score, confusion_matrix, precision_score
gnb = GaussianNB()
mnb = MultinomialNB()
bnb = BernoulliNB()

# %%
gnb.fit(X_train, y_train)
y_pred_gnb = gnb.predict(X_test)
print(accuracy_score(y_test, y_pred_gnb))
print(precision_score(y_test, y_pred_gnb))
print(confusion_matrix(y_test, y_pred_gnb))
# Out:
# 0.8607350096711799
# 0.4796380090497738
# [[784 115]
#  [ 29 106]]

# %%
mnb.fit(X_train, y_train)
y_pred_mnb = mnb.predict(X_test)
print(accuracy_score(y_test, y_pred_mnb))
print(precision_score(y_test, y_pred_mnb))
print(confusion_matrix(y_test, y_pred_mnb))
# Out:
# 0.9709864603481625
# 1.0
# [[899   0]
#  [ 30 105]]

# %%
bnb.fit(X_train, y_train)
y_pred_bnb = bnb.predict(X_test)
print(accuracy_score(y_test, y_pred_bnb))
print(precision_score(y_test, y_pred_bnb))
print(confusion_matrix(y_test, y_pred_bnb))
# Out:
# 0.9738878143133463
# 0.95
# [[893   6]
#  [ 21 114]]

# %% [markdown]
# # `tfidf->mnb`

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.naive_bayes import MultinomialNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import BaggingClassifier
from sklearn.ensemble import ExtraTreesClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier

# %% [markdown]
# # Evalution

# %%
svc = SVC(kernel='sigmoid', gamma=1.0)
knc = KNeighborsClassifier()
mnb = MultinomialNB()
dtc = DecisionTreeClassifier(max_depth=5)
lrc = LogisticRegression(solver='liblinear', penalty='l1')
rfc = RandomForestClassifier(n_estimators=50, random_state=2)
abc = AdaBoostClassifier(n_estimators=50, random_state=2)
bc = BaggingClassifier(n_estimators=50, random_state=2)
etc = ExtraTreesClassifier(n_estimators=50, random_state=2)
gbdt = GradientBoostingClassifier(n_estimators=50,random_state=2)
xgb = XGBClassifier(n_estimators=50,random_state=2)

# %%
clfs = {
    'SVC' : svc,
    'KN' : knc, 
    'NB': mnb, 
    'DT': dtc, 
    'LR': lrc, 
    'RF': rfc, 
    'AdaBoost': abc, 
    'BgC': bc, 
    'ETC': etc,
    'GBDT':gbdt,
    'xgb':xgb
}

# %%
def train_classifier(clf,X_train,y_train,X_test,y_test):
    clf.fit(X_train,y_train)
    y_pred = clf.predict(X_test)
    accuracy = accuracy_score(y_test,y_pred)
    precision = precision_score(y_test,y_pred)
    
    return accuracy,precision

# %%
train_classifier(svc,X_train,y_train,X_test,y_test)
# Out:
# (0.9729206963249516, 0.9826086956521739)

# %%
accuracy_scores = []
precision_scores = []

for name,clf in clfs.items():
    
    current_accuracy,current_precision = train_classifier(clf, X_train,y_train,X_test,y_test)
    
    print("For ",name)
    print("Accuracy - ",current_accuracy)
    print("Precision - ",current_precision)
    
    accuracy_scores.append(current_accuracy)
    precision_scores.append(current_precision)
# Out:
# For  SVC
# Accuracy -  0.9729206963249516
# Precision -  0.9826086956521739
# For  KN
# Accuracy -  0.913926499032882
# Precision -  1.0
# For  NB
# Accuracy -  0.9709864603481625
# Precision -  1.0
# For  DT
# Accuracy -  0.9294003868471954
# Precision -  0.851063829787234
# For  LR
# Accuracy -  0.9593810444874274
# Precision -  0.9619047619047619
# For  RF
# Accuracy -  0.9738878143133463
# Precision -  0.9827586206896551
# For  AdaBoost
# Accuracy -  0.9584139264990329
# Precision -  0.9137931034482759
# For  BgC
# Accuracy -  0.9584139264990329
# Precision -  0.8870967741935484
# For  ETC
# Accuracy -  0.9690522243713733
# Precision -  0.9572649572649573
# For  GBDT
# Accuracy -  0.9487427466150871
# Precision -  0.967391304347826
# For  xgb
# Accuracy -  0.9671179883945842
# Precision -  0.9487179487179487

# %%
performance_df = pd.DataFrame({'Algorithm':clfs.keys(),
                               'Accuracy':accuracy_scores,
                               'Precision':precision_scores}).sort_values(['Precision','Accuracy'],ascending=False)
performance_df
# Out:
#    Algorithm  Accuracy  Precision
# 2         NB  0.970986   1.000000
# 1         KN  0.913926   1.000000
# 5         RF  0.973888   0.982759
# 0        SVC  0.972921   0.982609
# 9       GBDT  0.948743   0.967391
# 4         LR  0.959381   0.961905
# 8        ETC  0.969052   0.957265
# 10       xgb  0.967118   0.948718
# 6   AdaBoost  0.958414   0.913793
# 7        BgC  0.958414   0.887097
# 3         DT  0.929400   0.851064

# %%
performance_df1 = pd.melt(performance_df, id_vars = "Algorithm")
performance_df1
# Out:
#    Algorithm   variable     value
# 0         NB   Accuracy  0.970986
# 1         KN   Accuracy  0.913926
# 2         RF   Accuracy  0.973888
# 3        SVC   Accuracy  0.972921
# 4       GBDT   Accuracy  0.948743
# 5         LR   Accuracy  0.959381
# 6        ETC   Accuracy  0.969052
# 7        xgb   Accuracy  0.967118
# 8   AdaBoost   Accuracy  0.958414
# 9        BgC   Accuracy  0.958414
# 10        DT   Accuracy  0.929400
# 11        NB  Precision  1.000000
# 12        KN  Precision  1.000000
# 13        RF  Precision  0.982759
# 14       SVC  Precision  0.982609
# 15      GBDT  Precision  0.967391
# 16        LR  Precision  0.961905
# 17       ETC  Precision  0.957265
# 18       xgb  Precision  0.948718
# 19  AdaBoost  Precision  0.913793
# 20       BgC  Precision  0.887097
# 21        DT  Precision  0.851064

# %%
sns.catplot(x = 'Algorithm', y='value', 
               hue = 'variable',data=performance_df1, kind='bar',height=5)
plt.ylim(0.5,1.0)
plt.xticks(rotation='vertical')
plt.show()

# %%
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_max_ft_3000':accuracy_scores,'Precision_max_ft_3000':precision_scores}).sort_values('Precision_max_ft_3000',ascending=False)
temp_df = pd.DataFrame({'Algorithm':clfs.keys(),'Accuracy_scaling':accuracy_scores,'Precision_scaling':precision_scores}).sort_values('Precision_scaling',ascending=False)

# %%
import pickle
pickle.dump(tfidf, open('vectorizer.pkl', 'wb'))
pickle.dump(mnb, open('model.pkl', 'wb'))
